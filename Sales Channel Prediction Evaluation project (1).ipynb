# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset and make first column as row number
ad=pd.read_csv('Desktop/Datatrained-main/advertising.csv')

# %%
ad
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
ad.shape
# Out:
# (200, 4)

# %% [markdown]
# Observation - The above data is for dollars(in thousands of dollars) spent on advertising in TV, Radio and Newspaper channel.
#
# Sales - The sales data shows sales of single project(in thousands of items) in market.

# %%
# Checking null vales
ad.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# Observation - There is no null values present in the given dataset.

# %%
# Checking data info
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# Observation - There are total 200 rows and 4 columns. There is no missing values and all the data in float64 data type.

# %%
ad.shape
# Out:
# (200, 4)

# %%
# Checking null values using heatmap
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(ad.isnull())
# Out:
# <Axes: >

# %%
# Checking columns name
ad.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # Summary Statistics

# %%
ad.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Observation - There is huge difference between 75% and maximum in column newspaper, So possibly outliers present.
#
# The minimum sales is 1.60 and maximum is 27.
#
# Std is maximum in TV.

# %%
# Checking correlation 
# multivariate analysis

ad_cor=ad.corr()
ad_cor
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %% [markdown]
# We can see correlation between two columns using above data.

# %%
# Use heatmap to check correlation for better understanding.
sns.heatmap(data=ad_cor,annot=True)
# Out:
# <Axes: >

# %%
ad.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# Observation - We can see there is little high correlation between tv and sales, and very low correlation between newspaper and sales.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariate Analysis

# %%
#Checking total amount spent tv,radio and newspaper
print('Amount spent on radio:',ad['Radio'].sum())
print('Amount spent on newspaper:',ad['Newspaper'].sum())
print('Amount spent on sales:',ad['Sales'].sum())
print('Amount spent on TV:',ad['TV'].sum())
# Out:
# Amount spent on radio: 4652.800000000001
# Amount spent on newspaper: 6110.799999999999
# Amount spent on sales: 3026.1000000000004
# Amount spent on TV: 29408.5

# %% [markdown]
# Observation - We can see highest amount spent on TV.

# %%
ad['TV'].plot.hist(bins=21)
plt.title('Histogram of TV')
plt.show()

# %%
ad['Radio'].plot.hist(bins=21)
plt.title('Histogram of radio')
plt.show()

# %%
ad['Newspaper'].plot.hist(bins=21)
plt.title('Histogram of newspaper')
plt.show()

# %%
sns.set (style='whitegrid')
sns.violinplot(ad['TV'])
plt.show()

# %% [markdown]
# Observation - We can see avarage 180 to 240 ((in thousands of dollars)) spent on advertising for most products.

# %%
sns.set (style='whitegrid')
sns.violinplot(ad['Radio'])
plt.show()

# %% [markdown]
# Observation - We can see avarage 5 to 20 ((in thousands of dollars)) spent on advertising for most products.

# %%
sns.set (style='whitegrid')
sns.violinplot(ad['Newspaper'])
plt.show()

# %% [markdown]
# Observation - We can see avarage 10 to 30 ((in thousands of dollars)) spent on advertising for most products.

# %% [markdown]
# # Bivariate Analysis

# %%
# Checking relationship between advertising channel and sale using scatter plot and pair plot
sns.set(style='darkgrid')
plt.scatter(ad['TV'],ad['Sales'])
plt.xlabel('TV')
plt.ylabel('sales')
plt.title('Scatter plot of TV vs sales')
plt.show()

# %% [markdown]
# Observation - we can see there is positive relation between TV and sales, The graph shows more amount spent on tv the sales continuously increase.

# %%
sns.set(style='darkgrid')
plt.scatter(ad['Radio'],ad['Sales'])
plt.xlabel('radio')
plt.ylabel('sales')
plt.title('Scatter plot of radio vs sales')
plt.show()

# %% [markdown]
# Observation - we can see there is low relation between radio and sales, The graph shows more amount spent on radio the sales not very much increase.

# %%
sns.set(style='darkgrid')
plt.scatter(ad['Newspaper'],ad['Sales'])
plt.xlabel('newspaper')
plt.ylabel('sales')
plt.title('Scatter plot of newspaper vs sales')
plt.show()

# %% [markdown]
# Observation - we can see there is very low relation between radio and sales, The graph shows more amount spent on radio, the sales not increase.

# %%
sns.pairplot(ad, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', size=9, aspect=0.7, kind='reg')

# %% [markdown]
# # Plotting Outliers

# %% [raw]
# ad.columns

# %%
ad['TV'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Observation - no outliers present.

# %%
ad['Radio'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Observation - No outliers present.

# %%
ad['Newspaper'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# Observation - Possibly outliers present in newspaper column.

# %% [markdown]
# # check the distribution of Skewnewss

# %%
collist=ad.columns.values
ncol=10
nrow=5

plt.figure(figsize=(20,10))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(ad[collist[i]],color='green')
    plt.tight_layout()

# %%
#Checking skewnewss
ad.skew()
# Out:
# TV          -0.069853
# Radio        0.094175
# Newspaper    0.894720
# Sales       -0.073739
# dtype: float64

# %%
# Treating skewness via log method

for col in ad.columns:
    if ad[col].skew()>0.55:
        ad[col]=np.log1p(ad[col])

# %%
# Checking skewness again
ad.skew()
# Out:
# TV          -0.069853
# Radio        0.094175
# Newspaper   -0.799875
# Sales       -0.073739
# dtype: float64

# %%
for i in ad.columns:
    sns.distplot(ad[i])
    plt.show()

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(ad))
z
# Out:
#            TV     Radio  Newspaper     Sales
# 0    0.969852  0.981522   1.270548  1.322319
# 1    1.197376  1.082808   0.784008  0.897515
# 2    1.516155  1.528463   1.272195  0.593948
# 3    0.052050  1.217855   1.079221  0.259834
# 4    0.394182  0.841614   1.077274  0.525455
# ..        ...       ...        ...       ...
# 195  1.270941  1.321031   0.530505  1.428757
# 196  0.617035  1.240003   1.093193  0.214489
# 197  0.349810  0.942899   1.332444  0.062706
# 198  1.594565  1.265121   1.220018  1.967398
# 199  0.993206  0.990165   1.019319  0.620320
#
# [200 rows x 4 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([33], dtype=int64), array([2], dtype=int64))

# %%
ad_new=ad[(z<3).all(axis=1)]

# %%
print(ad.shape)
# Out:
# (200, 4)

# %%
print(ad_new.shape)
# Out:
# (199, 4)

# %%
ad_new
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8   4.251348   22.1
# 1     44.5   39.3   3.830813   10.4
# 2     17.2   45.9   4.252772   12.0
# 3    151.5   41.3   4.085976   16.5
# 4    180.8   10.8   4.084294   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7   2.694627    7.6
# 196   94.2    4.9   2.208274   14.0
# 197  177.0    9.3   2.001480   14.8
# 198  283.6   42.0   4.207673   25.5
# 199  232.1    8.6   2.272126   18.4
#
# [199 rows x 4 columns]

# %% [markdown]
# Observation - Now we can see one row removed from dataset due to outliers.

# %% [markdown]
# ### From our analysis investing in tv advertisements contributed more to our sales.
# ### I would advise we spend more on tv adverts and cut spending on newspaper and radio adverts

# %% [markdown]
# # Model Training

# %%
# Separating data into input and output variables.

ad_x=ad_new.drop(columns=['Sales'])

# %%
y=pd.DataFrame(ad_new['Sales'])

# %%
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2     12.0
# 3     16.5
# 4     17.9
# ..     ...
# 195    7.6
# 196   14.0
# 197   14.8
# 198   25.5
# 199   18.4
#
# [199 rows x 1 columns]

# %%
# Scaling the input Variable

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ad_x)
x=pd.DataFrame(x,columns=ad_x.columns)

# %%
# Checking skewness again
x.skew()
# Out:
# TV          -0.063150
# Radio        0.090691
# Newspaper   -0.717354
# dtype: float64

# %%
# Make input and output variables into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
# Checking train and test data size
print(x_train.shape,'\t',x_test.shape)
# Out:
# (159, 3) 	 (40, 3)

# %%
print(y_train.shape,'\t',y_test.shape)
# Out:
# (159, 1) 	 (40, 1)

# %%
# Importing models library

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
# Importing error metrics

from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
# Using algorithms via for loop

model=[LinearRegression(),Lasso(),Ridge(),ElasticNet(),SVR(),KNeighborsRegressor(),DecisionTreeRegressor()]
for p in model:
    p.fit(x_train,y_train)
    print('Score of', p , 'is:' , p.score(x_train,y_train))
    predp=p.predict(x_test)
    print('Error:')
    print('Mean absolute error:', mean_absolute_error(y_test,predp))
    print('Mean squared error:', mean_squared_error(y_test,predp))
    print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,predp)))
    print('r2_score:', r2_score(y_test,predp))
    print('********************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is: 0.9049825831734656
# Error:
# Mean absolute error: 1.1483648633241235
# Mean squared error: 2.1780421669264753
# Root Mean squared error: 1.4758191511585947
# r2_score: 0.899646706484614
# ********************************************************************************************
#
#
# Score of Lasso() is: 0.8416875343981849
# Error:
# Mean absolute error: 1.3637883557385657
# Mean squared error: 3.0216338649154744
# Root Mean squared error: 1.7382847479384598
# r2_score: 0.8607782187386231
# ********************************************************************************************
#
#
# Score of Ridge() is: 0.9049504243027671
# Error:
# Mean absolute error: 1.1385733777168956
# Mean squared error: 2.155638907845864
# Root Mean squared error: 1.4682094223392874
# r2_score: 0.9006789366536885
# ********************************************************************************************
#
#
# Score of ElasticNet() is: 0.7569073841310706
# Error:
# Mean absolute error: 1.658957259224612
# Mean squared error: 4.454404049011369
# Root Mean squared error: 2.110545912557073
# r2_score: 0.7947633320628673
# ********************************************************************************************
#
#
# Score of SVR() is: 0.8585579467454794
# Error:
# Mean absolute error: 0.9969496828434732
# Mean squared error: 1.6089110985183634
# Root Mean squared error: 1.2684285941740525
# r2_score: 0.9258694206377016
# ********************************************************************************************
#
#
# Score of KNeighborsRegressor() is: 0.9255574094479568
# Error:
# Mean absolute error: 1.1400000000000001
# Mean squared error: 2.0857600000000005
# Root Mean squared error: 1.4442160503193422
# r2_score: 0.9038986073543187
# ********************************************************************************************
#
#
# Score of DecisionTreeRegressor() is: 1.0
# Error:
# Mean absolute error: 0.9024999999999999
# Mean squared error: 1.3572499999999998
# Root Mean squared error: 1.1650107295643246
# r2_score: 0.937464705829841
# ********************************************************************************************

# %%
# Finding out best paramter using GridsearchCV
from sklearn.model_selection import GridSearchCV
dt=DecisionTreeRegressor()
parameters={'random_state':range(42,100)}
gc=GridSearchCV(dt,parameters)
gc.fit(x,y)
gc.best_params_
# Out:
# {'random_state': 51}

# %%
#Using DecisionTreeRegressor model with best results

dtc=DecisionTreeRegressor(criterion='friedman_mse',random_state=42)
dtc.fit(x_train,y_train)
print('Score:', dtc.score(x_train,y_train))
preddt=dtc.predict(x_test)
print('\n')
print('Mean absolute error:', mean_absolute_error(y_test,preddt))
print('Mean squared error:', mean_squared_error(y_test,preddt))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,preddt)))
print('\n')
print('r2_score:', r2_score(y_test,preddt))
# Out:
# Score: 1.0
#
#
# Mean absolute error: 0.9075
# Mean squared error: 1.2857499999999997
# Root Mean squared error: 1.133909167438027
#
#
# r2_score: 0.940759068351975

# %%
# Cross validate of DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
score=cross_val_score(dtc,x,y,cv=5,scoring='r2')
print('Score:', score)
print('Mean Score:', score.std())
print('Standard Deviation:', score.std())
# Out:
# Score: [0.87807415 0.94612968 0.88241122 0.9325287  0.91279654]
# Mean Score: 0.026834173454014985
# Standard Deviation: 0.026834173454014985

# %% [markdown]
# # Using Ensemble Technique to boostup score

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor(n_estimators=100,random_state=70)
rf.fit(x_train,y_train)
print('score:',rf.score(x_train,y_train))
predrf=rf.predict(x_test)
print('\n')
print('Mean absolute error:', mean_absolute_error(y_test,predrf))
print('Mean squared error:', mean_squared_error(y_test,predrf))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,predrf)))
print('\n')
print('r2_score:', r2_score(y_test,predrf))
# Out:
# score: 0.9921638085407392
#
#
# Mean absolute error: 0.7307750000000021
# Mean squared error: 0.7749527750000031
# Root Mean squared error: 0.8803140206767146
#
#
# r2_score: 0.9642940506519755

# %%
from sklearn.ensemble import AdaBoostRegressor


ad=AdaBoostRegressor(base_estimator=dtc,n_estimators=20,learning_rate=1.0,random_state=70)
ad.fit(x_train,y_train)
print('score:',ad.score(x_train,y_train))
predad=ad.predict(x_test)
print('\n')
print('Mean absolute error:', mean_absolute_error(y_test,predad))
print('Mean squared error:', mean_squared_error(y_test,predad))
print('Root Mean squared error:', np.sqrt(mean_squared_error(y_test,predad)))
print('\n')
print('r2_score:', r2_score(y_test,predad))
# Out:
# score: 0.9995067885558437
#
#
# Mean absolute error: 0.6474999999999997
# Mean squared error: 0.7017499999999997
# Root Mean squared error: 0.8377051987423736
#
#
# r2_score: 0.9676668685327618

# %% [markdown]
# RandomForestRegressor is working well because it gives the best r2 score. So i save RandomForestRegressor as my final Model.

# %%
# Cross validate of RandomForestRegressor
from sklearn.model_selection import cross_val_score
score=cross_val_score(rf,x,y,cv=5,scoring='r2')
print('Score:', score)
print('Mean Score:', score.std())
print('Standard Deviation:', score.std())
# Out:
# Score: [0.94054498 0.97439221 0.94617239 0.91161041 0.94963254]
# Mean Score: 0.02009998793632491
# Standard Deviation: 0.02009998793632491

# %%
# Plotting scatter plot between test data and predicted data for RandomForestRegressor
plt.scatter(y_test,predrf)
plt.xlabel('y_test')
plt.ylabel('Predicted y')
plt.title('Test data and predicted data')
plt.show()

# %%
plt.scatter(y_test,predad)
plt.xlabel('y_test')
plt.ylabel('Predicted y')
plt.title('Test data and predicted data')
plt.show()

# %%
plt.scatter(y_test,preddt)
plt.xlabel('y_test')
plt.ylabel('Predicted y')
plt.title('Test data and predicted data')
plt.show()

# %%
# Saving the RandomForestRegressor\
import joblib
joblib.dump(rf,'Sales Channel Prediction.pkl')
# Out:
# ['Sales Channel Prediction.pkl']
